# %%
from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from keras.optimizers import SGD,Adam
import numpy as np
import matplotlib.pyplot as plt
from utils import WeightReader, decode_netout, draw_boxes, normalize

# %%
batch_size = 128
num_classes = 80
epochs = 5

# %%
#perform data prep

# %%
model = Sequential()

model.add(keras.layers.BatchNormalization(input_shape=(448,448,3), name="norm_1"))
model.add(Conv2D(16, (3,3), input_shape=(448,448,3), strides=1, name="conv_1"))
model.add(keras.layers.LeakyReLU(alpha=0.1))

model.add(MaxPool2D((2,2)))

model.add(keras.layers.BatchNormalization(name="norm_1"))
model.add(Conv2D(32, (3,3), strides=1, name="conv_2"))
model.add(keras.layers.LeakyReLU(alpha=0.1))

model.add(MaxPool2D((2,2)))

model.add(keras.layers.BatchNormalization())
model.add(Conv2D(64, (3,3), strides=1, name="conv_3"))
model.add(keras.layers.LeakyReLU(alpha=0.1))

model.add(MaxPool2D((2,2)))

model.add(keras.layers.BatchNormalization())
model.add(Conv2D(128, (3,3), strides=1, name="conv_4"))
model.add(keras.layers.LeakyReLU(alpha=0.1))

model.add(MaxPool2D((2,2)))

model.add(keras.layers.BatchNormalization())
model.add(Conv2D(256, (3,3), strides=1, name="conv_5"))
model.add(keras.layers.LeakyReLU(alpha=0.1))

model.add(MaxPool2D((2,2)))

model.add(keras.layers.BatchNormalization())
model.add(Conv2D(512, (3,3), strides=1, name="conv_6"))
model.add(keras.layers.LeakyReLU(alpha=0.1))

model.add(MaxPool2D((2,2)))

model.add(keras.layers.BatchNormalization())
model.add(Conv2D(1024, (3,3), strides=1, name="conv_7"))
model.add(keras.layers.LeakyReLU(alpha=0.1))

model.add(keras.layers.BatchNormalization())
model.add(Conv2D(1024, (3,3), strides=1, name="conv_8"))
model.add(keras.layers.LeakyReLU(alpha=0.1))

model.add(keras.layers.BatchNormalization())
model.add(Conv2D(425, (1,1), strides=1, activation = "linear", name="conv_9"))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_19 (Batc (None, 448, 448, 3)       12
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 446, 446, 16)      448
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 446, 446, 16)      0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 223, 223, 16)      0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 223, 223, 16)      64
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 221, 221, 32)      4640
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 221, 221, 32)      0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 110, 110, 32)      0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 110, 110, 32)      128
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 108, 108, 64)      18496
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 108, 108, 64)      0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 54, 54, 64)        0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 54, 54, 64)        256
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 52, 52, 128)       73856
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 52, 52, 128)       0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 26, 26, 128)       0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 26, 26, 128)       512
# _________________________________________________________________
# conv_5 (Conv2D)              (None, 24, 24, 256)       295168
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 24, 24, 256)       0
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 12, 12, 256)       0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 12, 12, 256)       1024
# _________________________________________________________________
# conv_6 (Conv2D)              (None, 10, 10, 512)       1180160
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 10, 10, 512)       0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 5, 5, 512)         0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv_7 (Conv2D)              (None, 3, 3, 1024)        4719616
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 3, 3, 1024)        0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 3, 3, 1024)        4096
# _________________________________________________________________
# conv_8 (Conv2D)              (None, 1, 1, 1024)        9438208
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 1, 1, 1024)        0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 1, 1, 1024)        4096
# _________________________________________________________________
# conv_9 (Conv2D)              (None, 1, 1, 425)         435625
# =================================================================
# Total params: 16,178,453
# Trainable params: 16,172,335
# Non-trainable params: 6,118
# _________________________________________________________________

# %%
wt_path = 'tinyyolo.weights'
weight_reader = WeightReader(wt_path)
weight_reader.reset()
nb_conv = 9

for i in range(1, nb_conv+1):
    conv_layer = model.get_layer('conv_' + str(i))
    
    if i < nb_conv:
        norm_layer = model.get_layer('norm_' + str(i))
        
        size = np.prod(norm_layer.get_weights()[0].shape)

        beta  = weight_reader.read_bytes(size)
        gamma = weight_reader.read_bytes(size)
        mean  = weight_reader.read_bytes(size)
        var   = weight_reader.read_bytes(size)

        weights = norm_layer.set_weights([gamma, beta, mean, var])       
        
    if len(conv_layer.get_weights()) > 1:
        bias   = weight_reader.read_bytes(np.prod(conv_layer.get_weights()[1].shape))
        kernel = weight_reader.read_bytes(np.prod(conv_layer.get_weights()[0].shape))
        kernel = kernel.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
        kernel = kernel.transpose([2,3,1,0])
        conv_layer.set_weights([kernel, bias])
    else:
        kernel = weight_reader.read_bytes(np.prod(conv_layer.get_weights()[0].shape))
        kernel = kernel.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
        kernel = kernel.transpose([2,3,1,0])
        conv_layer.set_weights([kernel])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8a6da3be2100> in <module>()
#       8
#       9     if i < nb_conv:
# ---> 10         norm_layer = model.get_layer('norm_' + str(i))
#      11
#      12         size = np.prod(norm_layer.get_weights()[0].shape)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/models.py in get_layer(self, name, index)
#     542         if not self.built:
#     543             self.build()
# --> 544         return self.model.get_layer(name, index)
#     545
#     546     def call(self, inputs, mask=None):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/topology.py in get_layer(self, name, index)
#    1885                 return layer
#    1886
# -> 1887         raise ValueError('No such layer: ' + name)
#    1888
#    1889     @property
#
# ValueError: No such layer: norm_1
